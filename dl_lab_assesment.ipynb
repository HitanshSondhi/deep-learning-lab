# %% [markdown]
# <a href="https://colab.research.google.com/github/HitanshSondhi/deep-learning-lab/blob/main/dl_lab_assesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Synthetic dataset
texts = [
    "I love this chatbot", "This is amazing", "I am so happy", "Great job",
    "I hate this chatbot", "This is terrible", "I am sad", "Bad experience"
]
labels = [1, 1, 1, 1, 0, 0, 0, 0]

# Tokenize and pad
tokenizer = Tokenizer(num_words=1000)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
X = pad_sequences(sequences, maxlen=5)
y = np.array(labels)

# Build model
model = Sequential([
    Embedding(input_dim=1000, output_dim=16, input_length=5),
    SimpleRNN(8),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X, y, epochs=10, verbose=2)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 - 3s - 3s/step - accuracy: 0.3750 - loss: 0.7037
# Epoch 2/10
# 1/1 - 0s - 199ms/step - accuracy: 0.5000 - loss: 0.6994
# Epoch 3/10
# 1/1 - 0s - 80ms/step - accuracy: 0.5000 - loss: 0.6952
# Epoch 4/10
# 1/1 - 0s - 137ms/step - accuracy: 0.6250 - loss: 0.6910
# Epoch 5/10
# 1/1 - 0s - 78ms/step - accuracy: 0.6250 - loss: 0.6869
# Epoch 6/10
# 1/1 - 0s - 89ms/step - accuracy: 0.6250 - loss: 0.6828
# Epoch 7/10
# 1/1 - 0s - 83ms/step - accuracy: 0.6250 - loss: 0.6787
# Epoch 8/10
# 1/1 - 0s - 86ms/step - accuracy: 0.6250 - loss: 0.6746
# Epoch 9/10
# 1/1 - 0s - 81ms/step - accuracy: 0.6250 - loss: 0.6705
# Epoch 10/10
# 1/1 - 0s - 76ms/step - accuracy: 0.6250 - loss: 0.6665

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Bidirectional, Dense

# Load dataset
num_words = 10000
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=num_words)
X_train = pad_sequences(X_train, maxlen=200)
X_test = pad_sequences(X_test, maxlen=200)

# Build model
model = Sequential([
    Embedding(num_words, 128),
    Bidirectional(LSTM(64)),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=2, batch_size=64, validation_split=0.2)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/2
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 166s 516ms/step - accuracy: 0.6899 - loss: 0.5572 - val_accuracy: 0.8654 - val_loss: 0.3244
# Epoch 2/2
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 160s 512ms/step - accuracy: 0.8954 - loss: 0.2637 - val_accuracy: 0.8382 - val_loss: 0.3520

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense

# Generate synthetic temperature data
np.random.seed(42)
temps = np.sin(np.arange(0, 1000) * 0.05) * 10 + 25 + np.random.normal(0, 0.5, 1000)

# Prepare data (7 days → next day)
X, y = [], []
for i in range(len(temps)-7):
    X.append(temps[i:i+7])
    y.append(temps[i+7])
X, y = np.array(X), np.array(y)
X = X.reshape((X.shape[0], X.shape[1], 1))

# Build model
model = Sequential([
    GRU(32, input_shape=(7,1)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=20, verbose=2)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 32/32 - 2s - 72ms/step - loss: 615.7605
# Epoch 2/20
# 32/32 - 0s - 11ms/step - loss: 522.3964
# Epoch 3/20
# 32/32 - 0s - 11ms/step - loss: 427.9969
# Epoch 4/20
# 32/32 - 0s - 12ms/step - loss: 349.2258
# Epoch 5/20
# 32/32 - 0s - 10ms/step - loss: 301.6880
# Epoch 6/20
# 32/32 - 0s - 11ms/step - loss: 268.0576
# Epoch 7/20
# 32/32 - 1s - 21ms/step - loss: 232.3955
# Epoch 8/20
# 32/32 - 0s - 8ms/step - loss: 204.6337
# Epoch 9/20
# 32/32 - 0s - 8ms/step - loss: 182.8657
# Epoch 10/20
# 32/32 - 0s - 6ms/step - loss: 164.4628
# Epoch 11/20
# 32/32 - 0s - 10ms/step - loss: 147.9513
# Epoch 12/20
# 32/32 - 0s - 7ms/step - loss: 133.3356
# Epoch 13/20
# ...

# %%
import pandas as pd

# Sample SMS data
data = {
    "text": [
        "Congratulations! You won a free ticket.",
        "Please call your mom.",
        "Win cash prizes now!!!",
        "Are you coming to class today?",
        "Claim your free gift card.",
        "Let’s meet at 6 pm."
    ],
    "labels": [1, 0, 1, 0, 1, 0]  # 1 = spam, 0 = not spam
}

df = pd.DataFrame(data)
df.to_csv("sms_data.csv", index=False)
print("✅ sms_data.csv created successfully.")
# Out:
# ✅ sms_data.csv created successfully.

# %%
# !pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.8/330.8 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 75.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 73.3 MB/s eta 0:00:00
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=71ad51cf49391a41be5e9b46cb73eca694f2d6c73a6f059e9ecd2449e80c0755
#   Stored in directory: /root/.cache/pip/wheels/5f/b8/73/0b2c1a76b701a677653dd79ece07cfabd7457989dbfbdcd8d7
# Successfully built seqeval
# ...

# %%
from simpletransformers.classification import ClassificationModel
import pandas as pd

model = ClassificationModel('bert', 'bert-base-uncased', num_labels=2, use_cuda=False)
train_df = pd.read_csv("sms_data.csv")
model.train_model(train_df)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 0it [00:00, ?it/s]
# ...
# Running Epoch 1 of 1:   0%|          | 0/1 [00:00<?, ?it/s]
# (1, 0.7195501327514648)

# %%
from transformers import ViTForImageClassification, ViTImageProcessor
from PIL import Image
import torch
import requests
from io import BytesIO

# Load pretrained ViT
model_name = "google/vit-base-patch16-224"
model = ViTForImageClassification.from_pretrained(model_name)
processor = ViTImageProcessor.from_pretrained(model_name)

# Example image URL
image_url = "https://www.gstatic.com/webp/gallery3/2.png"

# Download and open image from URL
response = requests.get(image_url)
image = Image.open(BytesIO(response.content)).convert("RGB")

inputs = processor(images=image, return_tensors="pt")

# Predict
with torch.no_grad():
    logits = model(**inputs).logits

predicted_class_idx = logits.argmax(-1).item()
print("Predicted class:", model.config.id2label[predicted_class_idx])
# Out:
# Predicted class: teddy, teddy bear

# %%
import requests

image_url = "https://images.unsplash.com/photo-1522069169771-ad5b23f6c55e?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D" # Example animal image URL
response = requests.get(image_url)

if response.status_code == 200:
    with open("animal.jpg", "wb") as f:
        f.write(response.content)
    print("✅ animal.jpg downloaded successfully.")
else:
    print(f"Failed to download image. Status code: {response.status_code}")

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.1 MB/s eta 0:00:00
# ...

# %%
import requests

image_url = "https://images.unsplash.com/photo-1533186413953-7261042e7243?q=80&w=2070&auto=format&fit=crop&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D" # Another example animal image URL
response = requests.get(image_url)

if response.status_code == 200:
    with open("animal.jpg", "wb") as f:
        f.write(response.content)
    print("✅ animal.jpg downloaded successfully.")
else:
    print(f"Failed to download image. Status code: {response.status_code}")

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Generator
class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(100, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 784),
            nn.Tanh()
        )
    def forward(self, z):
        return self.model(z).view(-1, 1, 28, 28)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(784, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        x = x.view(-1, 784)
        return self.model(x)

# Initialize models
G, D = Generator(), Discriminator()
criterion = nn.BCELoss()
optimizer_G = optim.Adam(G.parameters(), lr=0.0002)
optimizer_D = optim.Adam(D.parameters(), lr=0.0002)

# Training loop (synthetic demo)
for epoch in range(3):
    z = torch.randn(16, 100)
    fake_imgs = G(z)
    real_labels = torch.ones(16, 1)
    fake_labels = torch.zeros(16, 1)

    # Train Discriminator
    D.zero_grad()
    real_loss = criterion(D(torch.randn(16, 1, 28, 28)), real_labels)
    fake_loss = criterion(D(fake_imgs.detach()), fake_labels)
    D_loss = (real_loss + fake_loss) / 2
    D_loss.backward()
    optimizer_D.step()

    # Train Generator
    G.zero_grad()
    G_loss = criterion(D(fake_imgs), real_labels)
    G_loss.backward()
    optimizer_G.step()

    print(f"Epoch [{epoch+1}/3]  D_loss: {D_loss.item():.4f}  G_loss: {G_loss.item():.4f}")
# Out:
# Epoch [1/3]  D_loss: 0.6992  G_loss: 0.7103
# Epoch [2/3]  D_loss: 0.6881  G_loss: 0.6979
# Epoch [3/3]  D_loss: 0.6751  G_loss: 0.6875
